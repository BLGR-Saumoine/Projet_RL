# %%
import gymnasium as gym
from gymnasium.wrappers import FrameStackObservation
from gymnasium.wrappers import ResizeObservation
import ale_py
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from agent import Agent
from memories import *

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion() # interactive on

nbFrameStack = 4

# %%
env = gym.make("ALE/Pong-v5", obs_type="grayscale")
print(env.observation_space.shape)
env = ResizeObservation(env, (84, 84)) 
print(env.observation_space.shape)
env = FrameStackObservation(env, stack_size=nbFrameStack)
# Out:
# (210, 160)
# (84, 84)

# %% [markdown]
# ## Hyperparameters for dueling, no Double learning

# %%
BATCH_SIZE = 32
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.1
EPS_DECAY = 1000000
TAU = 0.005
LR = 1e-4
REPLAY_BUFFER_SIZE = 100000
trainingFrequency = 4
nbActions = env.action_space.n

# %% [markdown]
# # Hyperparameters for dueling, no Double learning and PER

# %%
BATCH_SIZE = 32
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.1
EPS_DECAY = 100000
TAU = 0.005
LR = 6.25e-5
REPLAY_BUFFER_SIZE = 100000
trainingFrequency = 4
nbActions = env.action_space.n

# %%
def trainModel(num_episodes = 600, numGameAVG = 5, doubleMode = False, nStep = 1, weightName = "Model", usePer = False) :
  finalScore = []

  for game in range(numGameAVG) :
    finalGameScore = []
    
    agent = Agent(n_FrameStack=nbFrameStack, n_actions=nbActions, lr=LR, gamma=GAMMA, tau=TAU, device=device,
                   epsDecay=EPS_DECAY, epsEnd=EPS_END, epsStart=EPS_START,use_double_dqn=doubleMode, 
                   )
    memoryBuffer = ReplayMemory(REPLAY_BUFFER_SIZE, usePer=usePer)

    for i_episode in range(num_episodes):
      nStepMemory = SmallMemory(nStep, GAMMA)

      currentGameScore = 0

      if i_episode == 0:
        state, info = env.reset(seed=game)
      else :
        state, info = env.reset()
      #state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0) /255.0
      state = torch.tensor(state, dtype=torch.uint8).unsqueeze(0)

      for t in count():
          action = agent.select_action(state)
          observation, reward, terminated, truncated, _ = env.step(action)

          currentGameScore += reward

          #reward_tensor = torch.tensor([reward/100.0], dtype=torch.float32) ça marchait pour Qbert mais ça m'a saboté pour Pong
          reward_tensor = torch.tensor([reward], dtype=torch.float32)
          next_state = torch.tensor(observation, dtype=torch.uint8).unsqueeze(0) #/255
          done = terminated or truncated

          prevTrans = nStepMemory.push(state, action, next_state, reward_tensor, done)

          if prevTrans is not None :
            memoryBuffer.push(*prevTrans)
            
          # Move to the next state
          state = next_state

          if agent.numberStep % trainingFrequency == 0:
            deltas, indexs = agent.optimizeModel(memoryBuffer, batch_size=BATCH_SIZE, nStep=nStep)

            # Soft update of the target network's weights
            # θ′ ← τ θ + (1 −τ )θ′
            agent.softUpdateNetwork()

          if done :
              lastMoves = nStepMemory.flush()
              for transitions in lastMoves:
                  memoryBuffer.push(*transitions)

              finalGameScore.append(currentGameScore)
              break
      print(f"Episode n°{i_episode}")
      print(f"reward : {currentGameScore}")
      print(f"Number of steps : {t + 1}")
      print("=" *20)

    finalScore.append(finalGameScore)

  torch.save(agent.onlineNetwork.state_dict(), weightName)
  return finalScore

# %%
finalScore = trainModel(1000, 1, doubleMode=False, nStep=3, weightName="PERDuelingPong3-Step.pth", usePer=True)

scores_bruts = finalScore[0] 

df_scores = pd.DataFrame({
    "Episode": range(len(scores_bruts)),
    "Reward": scores_bruts
})

nom_fichier_csv = "scores_PER_DuelingPong3-Step.csv"
df_scores.to_csv(nom_fichier_csv, index=False)


fenetre = 50
scores_lisses = pd.Series(scores_bruts).rolling(window=fenetre).mean()

plt.figure(figsize=(10, 6)) 


plt.plot(scores_bruts, alpha=0.2, color='blue', label='Episode Score')

plt.plot(scores_lisses, color='red', linewidth=2, label=f'Moving avergae (on {fenetre} ep.)')

plt.xlabel("Episode")
plt.ylabel("Score")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()
# Out:
# Episode n°0
# reward : -19.0
# Number of steps : 960
# ====================
# Episode n°1
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°2
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°3
# reward : -19.0
# Number of steps : 943
# ====================
# Episode n°4
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°5
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°6
# reward : -21.0
# Number of steps : 943
# ====================
# Episode n°7
# reward : -21.0
# Number of steps : 826
# ====================
# Episode n°8
# reward : -20.0
# Number of steps : 1072
# ====================
# Episode n°9
# reward : -20.0
# Number of steps : 1051
# ====================
# Episode n°10
# reward : -19.0
# Number of steps : 1158
# ====================
# Episode n°11
# reward : -21.0
# Number of steps : 872
# ====================
# Episode n°12
# reward : -21.0
# Number of steps : 845
# ====================
# Episode n°13
# reward : -20.0
# Number of steps : 951
# ====================
# Episode n°14
# reward : -21.0
# Number of steps : 1032
# ====================
# Episode n°15
# reward : -20.0
# Number of steps : 975
# ====================
# Episode n°16
# reward : -21.0
# Number of steps : 1006
# ====================
# Episode n°17
# reward : -21.0
# Number of steps : 1001
# ====================
# Episode n°18
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°19
# reward : -20.0
# Number of steps : 926
# ====================
# Episode n°20
# reward : -21.0
# Number of steps : 912
# ====================
# Episode n°21
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°22
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°23
# reward : -21.0
# Number of steps : 830
# ====================
# Episode n°24
# reward : -21.0
# Number of steps : 825
# ====================
# Episode n°25
# reward : -21.0
# Number of steps : 971
# ====================
# Episode n°26
# reward : -20.0
# Number of steps : 1188
# ====================
# Episode n°27
# reward : -19.0
# Number of steps : 1044
# ====================
# Episode n°28
# reward : -20.0
# Number of steps : 860
# ====================
# Episode n°29
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°30
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°31
# reward : -21.0
# Number of steps : 1064
# ====================
# Episode n°32
# reward : -21.0
# Number of steps : 886
# ====================
# Episode n°33
# reward : -20.0
# Number of steps : 1032
# ====================
# Episode n°34
# reward : -20.0
# Number of steps : 1113
# ====================
# Episode n°35
# reward : -21.0
# Number of steps : 1064
# ====================
# Episode n°36
# reward : -20.0
# Number of steps : 1026
# ====================
# Episode n°37
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°38
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°39
# reward : -21.0
# Number of steps : 940
# ====================
# Episode n°40
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°41
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°42
# reward : -21.0
# Number of steps : 826
# ====================
# Episode n°43
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°44
# reward : -20.0
# Number of steps : 927
# ====================
# Episode n°45
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°46
# reward : -21.0
# Number of steps : 882
# ====================
# Episode n°47
# reward : -21.0
# Number of steps : 820
# ====================
# Episode n°48
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°49
# reward : -20.0
# Number of steps : 1128
# ====================
# Episode n°50
# reward : -20.0
# Number of steps : 844
# ====================
# Episode n°51
# reward : -20.0
# Number of steps : 902
# ====================
# Episode n°52
# reward : -21.0
# Number of steps : 882
# ====================
# Episode n°53
# reward : -20.0
# Number of steps : 931
# ====================
# Episode n°54
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°55
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°56
# reward : -19.0
# Number of steps : 1009
# ====================
# Episode n°57
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°58
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°59
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°60
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°61
# reward : -21.0
# Number of steps : 932
# ====================
# Episode n°62
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°63
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°64
# reward : -19.0
# Number of steps : 973
# ====================
# Episode n°65
# reward : -20.0
# Number of steps : 871
# ====================
# Episode n°66
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°67
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°68
# reward : -18.0
# Number of steps : 1026
# ====================
# Episode n°69
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°70
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°71
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°72
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°73
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°74
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°75
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°76
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°77
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°78
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°79
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°80
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°81
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°82
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°83
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°84
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°85
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°86
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°87
# reward : -21.0
# Number of steps : 823
# ====================
# Episode n°88
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°89
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°90
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°91
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°92
# reward : -20.0
# Number of steps : 870
# ====================
# Episode n°93
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°94
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°95
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°96
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°97
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°98
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°99
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°100
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°101
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°102
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°103
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°104
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°105
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°106
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°107
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°108
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°109
# reward : -20.0
# Number of steps : 941
# ====================
# Episode n°110
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°111
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°112
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°113
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°114
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°115
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°116
# reward : -21.0
# Number of steps : 820
# ====================
# Episode n°117
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°118
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°119
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°120
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°121
# reward : -21.0
# Number of steps : 843
# ====================
# Episode n°122
# reward : -20.0
# Number of steps : 897
# ====================
# Episode n°123
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°124
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°125
# reward : -21.0
# Number of steps : 852
# ====================
# Episode n°126
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°127
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°128
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°129
# reward : -21.0
# Number of steps : 782
# ====================
# Episode n°130
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°131
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°132
# reward : -21.0
# Number of steps : 764
# ====================
# Episode n°133
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°134
# reward : -18.0
# Number of steps : 1058
# ====================
# Episode n°135
# reward : -21.0
# Number of steps : 854
# ====================
# Episode n°136
# reward : -20.0
# Number of steps : 894
# ====================
# Episode n°137
# reward : -20.0
# Number of steps : 1100
# ====================
# Episode n°138
# reward : -21.0
# Number of steps : 854
# ====================
# Episode n°139
# reward : -20.0
# Number of steps : 870
# ====================
# Episode n°140
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°141
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°142
# reward : -20.0
# Number of steps : 987
# ====================
# Episode n°143
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°144
# reward : -20.0
# Number of steps : 866
# ====================
# Episode n°145
# reward : -20.0
# Number of steps : 837
# ====================
# Episode n°146
# reward : -20.0
# Number of steps : 870
# ====================
# Episode n°147
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°148
# reward : -20.0
# Number of steps : 870
# ====================
# Episode n°149
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°150
# reward : -19.0
# Number of steps : 934
# ====================
# Episode n°151
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°152
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°153
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°154
# reward : -21.0
# Number of steps : 843
# ====================
# Episode n°155
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°156
# reward : -21.0
# Number of steps : 811
# ====================
# Episode n°157
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°158
# reward : -20.0
# Number of steps : 1014
# ====================
# Episode n°159
# reward : -20.0
# Number of steps : 960
# ====================
# Episode n°160
# reward : -21.0
# Number of steps : 792
# ====================
# Episode n°161
# reward : -19.0
# Number of steps : 948
# ====================
# Episode n°162
# reward : -21.0
# Number of steps : 826
# ====================
# Episode n°163
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°164
# reward : -21.0
# Number of steps : 886
# ====================
# Episode n°165
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°166
# reward : -20.0
# Number of steps : 838
# ====================
# Episode n°167
# reward : -21.0
# Number of steps : 825
# ====================
# Episode n°168
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°169
# reward : -20.0
# Number of steps : 856
# ====================
# Episode n°170
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°171
# reward : -21.0
# Number of steps : 854
# ====================
# Episode n°172
# reward : -21.0
# Number of steps : 878
# ====================
# Episode n°173
# reward : -21.0
# Number of steps : 886
# ====================
# Episode n°174
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°175
# reward : -20.0
# Number of steps : 872
# ====================
# Episode n°176
# reward : -20.0
# Number of steps : 902
# ====================
# Episode n°177
# reward : -21.0
# Number of steps : 884
# ====================
# Episode n°178
# reward : -20.0
# Number of steps : 903
# ====================
# Episode n°179
# reward : -21.0
# Number of steps : 848
# ====================
# Episode n°180
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°181
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°182
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°183
# reward : -21.0
# Number of steps : 782
# ====================
# Episode n°184
# reward : -20.0
# Number of steps : 962
# ====================
# Episode n°185
# reward : -21.0
# Number of steps : 904
# ====================
# Episode n°186
# reward : -20.0
# Number of steps : 899
# ====================
# Episode n°187
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°188
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°189
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°190
# reward : -20.0
# Number of steps : 860
# ====================
# Episode n°191
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°192
# reward : -21.0
# Number of steps : 912
# ====================
# Episode n°193
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°194
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°195
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°196
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°197
# reward : -20.0
# Number of steps : 843
# ====================
# Episode n°198
# reward : -21.0
# Number of steps : 820
# ====================
# Episode n°199
# reward : -21.0
# Number of steps : 826
# ====================
# Episode n°200
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°201
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°202
# reward : -21.0
# Number of steps : 899
# ====================
# Episode n°203
# reward : -21.0
# Number of steps : 826
# ====================
# Episode n°204
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°205
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°206
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°207
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°208
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°209
# reward : -21.0
# Number of steps : 824
# ====================
# Episode n°210
# reward : -21.0
# Number of steps : 794
# ====================
# Episode n°211
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°212
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°213
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°214
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°215
# reward : -21.0
# Number of steps : 903
# ====================
# Episode n°216
# reward : -20.0
# Number of steps : 917
# ====================
# Episode n°217
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°218
# reward : -20.0
# Number of steps : 977
# ====================
# Episode n°219
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°220
# reward : -20.0
# Number of steps : 926
# ====================
# Episode n°221
# reward : -21.0
# Number of steps : 783
# ====================
# Episode n°222
# reward : -21.0
# Number of steps : 823
# ====================
# Episode n°223
# reward : -20.0
# Number of steps : 905
# ====================
# Episode n°224
# reward : -20.0
# Number of steps : 859
# ====================
# Episode n°225
# reward : -21.0
# Number of steps : 782
# ====================
# Episode n°226
# reward : -20.0
# Number of steps : 930
# ====================
# Episode n°227
# reward : -20.0
# Number of steps : 842
# ====================
# Episode n°228
# reward : -19.0
# Number of steps : 1059
# ====================
# Episode n°229
# reward : -20.0
# Number of steps : 902
# ====================
# Episode n°230
# reward : -19.0
# Number of steps : 1051
# ====================
# Episode n°231
# reward : -17.0
# Number of steps : 1166
# ====================
# Episode n°232
# reward : -20.0
# Number of steps : 1060
# ====================
# Episode n°233
# reward : -16.0
# Number of steps : 1467
# ====================
# Episode n°234
# reward : -18.0
# Number of steps : 1185
# ====================
# Episode n°235
# reward : -20.0
# Number of steps : 1101
# ====================
# Episode n°236
# reward : -20.0
# Number of steps : 902
# ====================
# Episode n°237
# reward : -20.0
# Number of steps : 1046
# ====================
# Episode n°238
# reward : -19.0
# Number of steps : 1037
# ====================
# Episode n°239
# reward : -18.0
# Number of steps : 1193
# ====================
# Episode n°240
# reward : -19.0
# Number of steps : 1138
# ====================
# Episode n°241
# reward : -15.0
# Number of steps : 1644
# ====================
# Episode n°242
# reward : -19.0
# Number of steps : 995
# ====================
# Episode n°243
# reward : -20.0
# Number of steps : 1025
# ====================
# Episode n°244
# reward : -19.0
# Number of steps : 1137
# ====================
# Episode n°245
# reward : -20.0
# Number of steps : 898
# ====================
# Episode n°246
# reward : -18.0
# Number of steps : 1399
# ====================
# Episode n°247
# reward : -18.0
# Number of steps : 1366
# ====================
# Episode n°248
# reward : -16.0
# Number of steps : 1611
# ====================
# Episode n°249
# reward : -19.0
# Number of steps : 1413
# ====================
# Episode n°250
# reward : -21.0
# Number of steps : 1062
# ====================
# Episode n°251
# reward : -17.0
# Number of steps : 1352
# ====================
# Episode n°252
# reward : -16.0
# Number of steps : 1469
# ====================
# Episode n°253
# reward : -17.0
# Number of steps : 1428
# ====================
# Episode n°254
# reward : -17.0
# Number of steps : 1452
# ====================
# Episode n°255
# reward : -18.0
# Number of steps : 1540
# ====================
# Episode n°256
# reward : -17.0
# Number of steps : 1591
# ====================
# Episode n°257
# reward : -19.0
# Number of steps : 1488
# ====================
# Episode n°258
# reward : -18.0
# Number of steps : 1429
# ====================
# Episode n°259
# reward : -16.0
# Number of steps : 1752
# ====================
# Episode n°260
# reward : -20.0
# Number of steps : 1340
# ====================
# Episode n°261
# reward : -16.0
# Number of steps : 1490
# ====================
# Episode n°262
# reward : -19.0
# Number of steps : 1406
# ====================
# Episode n°263
# reward : -21.0
# Number of steps : 980
# ====================
# Episode n°264
# reward : -19.0
# Number of steps : 1358
# ====================
# Episode n°265
# reward : -19.0
# Number of steps : 1260
# ====================
# Episode n°266
# reward : -18.0
# Number of steps : 1259
# ====================
# Episode n°267
# reward : -16.0
# Number of steps : 1494
# ====================
# Episode n°268
# reward : -19.0
# Number of steps : 1294
# ====================
# Episode n°269
# reward : -19.0
# Number of steps : 1244
# ====================
# Episode n°270
# reward : -19.0
# Number of steps : 1325
# ====================
# Episode n°271
# reward : -17.0
# Number of steps : 1624
# ====================
# Episode n°272
# reward : -17.0
# Number of steps : 1600
# ====================
# Episode n°273
# reward : -18.0
# Number of steps : 1339
# ====================
# Episode n°274
# reward : -16.0
# Number of steps : 1549
# ====================
# Episode n°275
# reward : -19.0
# Number of steps : 1351
# ====================
# Episode n°276
# reward : -19.0
# Number of steps : 1310
# ====================
# Episode n°277
# reward : -20.0
# Number of steps : 1211
# ====================
# Episode n°278
# reward : -19.0
# Number of steps : 1419
# ====================
# Episode n°279
# reward : -19.0
# Number of steps : 1290
# ====================
# Episode n°280
# reward : -19.0
# Number of steps : 1334
# ====================
# Episode n°281
# reward : -20.0
# Number of steps : 1354
# ====================
# Episode n°282
# reward : -18.0
# Number of steps : 1362
# ====================
# Episode n°283
# reward : -19.0
# Number of steps : 1286
# ====================
# Episode n°284
# reward : -20.0
# Number of steps : 1309
# ====================
# Episode n°285
# reward : -21.0
# Number of steps : 1142
# ====================
# Episode n°286
# reward : -21.0
# Number of steps : 1141
# ====================
# Episode n°287
# reward : -21.0
# Number of steps : 1103
# ====================
# Episode n°288
# reward : -19.0
# Number of steps : 1312
# ====================
# Episode n°289
# reward : -18.0
# Number of steps : 1208
# ====================
# Episode n°290
# reward : -16.0
# Number of steps : 1549
# ====================
# Episode n°291
# reward : -21.0
# Number of steps : 1237
# ====================
# Episode n°292
# reward : -19.0
# Number of steps : 1258
# ====================
# Episode n°293
# reward : -20.0
# Number of steps : 1262
# ====================
# Episode n°294
# reward : -20.0
# Number of steps : 1174
# ====================
# Episode n°295
# reward : -17.0
# Number of steps : 1624
# ====================
# Episode n°296
# reward : -18.0
# Number of steps : 1300
# ====================
# Episode n°297
# reward : -20.0
# Number of steps : 1262
# ====================
# Episode n°298
# reward : -20.0
# Number of steps : 1248
# ====================
# Episode n°299
# reward : -19.0
# Number of steps : 1382
# ====================
# Episode n°300
# reward : -18.0
# Number of steps : 1403
# ====================
# Episode n°301
# reward : -16.0
# Number of steps : 1363
# ====================
# Episode n°302
# reward : -20.0
# Number of steps : 1239
# ====================
# Episode n°303
# reward : -20.0
# Number of steps : 1189
# ====================
# Episode n°304
# reward : -20.0
# Number of steps : 1504
# ====================
# Episode n°305
# reward : -20.0
# Number of steps : 1180
# ====================
# Episode n°306
# reward : -18.0
# Number of steps : 1298
# ====================
# Episode n°307
# reward : -18.0
# Number of steps : 1465
# ====================
# Episode n°308
# reward : -21.0
# Number of steps : 1163
# ====================
# Episode n°309
# reward : -18.0
# Number of steps : 1249
# ====================
# Episode n°310
# reward : -20.0
# Number of steps : 1435
# ====================
# Episode n°311
# reward : -21.0
# Number of steps : 1021
# ====================
# Episode n°312
# reward : -20.0
# Number of steps : 1189
# ====================
# Episode n°313
# reward : -19.0
# Number of steps : 1199
# ====================
# Episode n°314
# reward : -20.0
# Number of steps : 1087
# ====================
# Episode n°315
# reward : -17.0
# Number of steps : 1464
# ====================
# Episode n°316
# reward : -21.0
# Number of steps : 1244
# ====================
# Episode n°317
# reward : -18.0
# Number of steps : 1463
# ====================
# Episode n°318
# reward : -18.0
# Number of steps : 1507
# ====================
# Episode n°319
# reward : -19.0
# Number of steps : 1487
# ====================
# Episode n°320
# reward : -18.0
# Number of steps : 1374
# ====================
# Episode n°321
# reward : -17.0
# Number of steps : 1575
# ====================
# Episode n°322
# reward : -16.0
# Number of steps : 1490
# ====================
# Episode n°323
# reward : -19.0
# Number of steps : 1404
# ====================
# Episode n°324
# reward : -13.0
# Number of steps : 1803
# ====================
# Episode n°325
# reward : -17.0
# Number of steps : 1615
# ====================
# Episode n°326
# reward : -16.0
# Number of steps : 1566
# ====================
# Episode n°327
# reward : -19.0
# Number of steps : 1492
# ====================
# Episode n°328
# reward : -13.0
# Number of steps : 1768
# ====================
# Episode n°329
# reward : -15.0
# Number of steps : 1598
# ====================
# Episode n°330
# reward : -18.0
# Number of steps : 1600
# ====================
# Episode n°331
# reward : -17.0
# Number of steps : 1536
# ====================
# Episode n°332
# reward : -16.0
# Number of steps : 1616
# ====================
# Episode n°333
# reward : -18.0
# Number of steps : 1531
# ====================
# Episode n°334
# reward : -18.0
# Number of steps : 1585
# ====================
# Episode n°335
# reward : -13.0
# Number of steps : 1851
# ====================
# Episode n°336
# reward : -19.0
# Number of steps : 1424
# ====================
# Episode n°337
# reward : -21.0
# Number of steps : 1435
# ====================
# Episode n°338
# reward : -16.0
# Number of steps : 1583
# ====================
# Episode n°339
# reward : -17.0
# Number of steps : 1560
# ====================
# Episode n°340
# reward : -20.0
# Number of steps : 1367
# ====================
# Episode n°341
# reward : -15.0
# Number of steps : 1666
# ====================
# Episode n°342
# reward : -19.0
# Number of steps : 1457
# ====================
# Episode n°343
# reward : -16.0
# Number of steps : 1733
# ====================
# Episode n°344
# reward : -16.0
# Number of steps : 1514
# ====================
# Episode n°345
# reward : -18.0
# Number of steps : 1842
# ====================
# Episode n°346
# reward : -16.0
# Number of steps : 1527
# ====================
# Episode n°347
# reward : -19.0
# Number of steps : 1374
# ====================
# Episode n°348
# reward : -14.0
# Number of steps : 1807
# ====================
# Episode n°349
# reward : -17.0
# Number of steps : 1803
# ====================
# Episode n°350
# reward : -18.0
# Number of steps : 1414
# ====================
# Episode n°351
# reward : -17.0
# Number of steps : 1605
# ====================
# Episode n°352
# reward : -17.0
# Number of steps : 1565
# ====================
# Episode n°353
# reward : -17.0
# Number of steps : 1617
# ====================
# Episode n°354
# reward : -19.0
# Number of steps : 1494
# ====================
# Episode n°355
# reward : -17.0
# Number of steps : 1694
# ====================
# Episode n°356
# reward : -17.0
# Number of steps : 1601
# ====================
# Episode n°357
# reward : -15.0
# Number of steps : 1598
# ====================
# Episode n°358
# reward : -21.0
# Number of steps : 1345
# ====================
# Episode n°359
# reward : -17.0
# Number of steps : 1746
# ====================
# Episode n°360
# reward : -15.0
# Number of steps : 1892
# ====================
# Episode n°361
# reward : -16.0
# Number of steps : 1525
# ====================
# Episode n°362
# reward : -17.0
# Number of steps : 1525
# ====================
# Episode n°363
# reward : -17.0
# Number of steps : 1473
# ====================
# Episode n°364
# reward : -19.0
# Number of steps : 1530
# ====================
# Episode n°365
# reward : -19.0
# Number of steps : 1494
# ====================
# Episode n°366
# reward : -16.0
# Number of steps : 1598
# ====================
# Episode n°367
# reward : -19.0
# Number of steps : 1476
# ====================
# Episode n°368
# reward : -18.0
# Number of steps : 1357
# ====================
# Episode n°369
# reward : -19.0
# Number of steps : 1506
# ====================
# Episode n°370
# reward : -20.0
# Number of steps : 1340
# ====================
# Episode n°371
# reward : -14.0
# Number of steps : 1954
# ====================
# Episode n°372
# reward : -17.0
# Number of steps : 1730
# ====================
# Episode n°373
# reward : -17.0
# Number of steps : 1492
# ====================
# Episode n°374
# reward : -17.0
# Number of steps : 1674
# ====================
# Episode n°375
# reward : -12.0
# Number of steps : 1969
# ====================
# Episode n°376
# reward : -17.0
# Number of steps : 1546
# ====================
# Episode n°377
# reward : -17.0
# Number of steps : 1725
# ====================
# Episode n°378
# reward : -18.0
# Number of steps : 1490
# ====================
# Episode n°379
# reward : -16.0
# Number of steps : 1679
# ====================
# Episode n°380
# reward : -19.0
# Number of steps : 1515
# ====================
# Episode n°381
# reward : -16.0
# Number of steps : 1721
# ====================
# Episode n°382
# reward : -21.0
# Number of steps : 1408
# ====================
# Episode n°383
# reward : -19.0
# Number of steps : 1485
# ====================
# Episode n°384
# reward : -21.0
# Number of steps : 1214
# ====================
# Episode n°385
# reward : -17.0
# Number of steps : 1666
# ====================
# Episode n°386
# reward : -18.0
# Number of steps : 1439
# ====================
# Episode n°387
# reward : -19.0
# Number of steps : 1602
# ====================
# Episode n°388
# reward : -15.0
# Number of steps : 1798
# ====================
# Episode n°389
# reward : -18.0
# Number of steps : 1517
# ====================
# Episode n°390
# reward : -16.0
# Number of steps : 1778
# ====================
# Episode n°391
# reward : -19.0
# Number of steps : 1578
# ====================
# Episode n°392
# reward : -18.0
# Number of steps : 1870
# ====================
# Episode n°393
# reward : -18.0
# Number of steps : 1475
# ====================
# Episode n°394
# reward : -15.0
# Number of steps : 1888
# ====================
# Episode n°395
# reward : -17.0
# Number of steps : 1648
# ====================
# Episode n°396
# reward : -15.0
# Number of steps : 1747
# ====================
# Episode n°397
# reward : -18.0
# Number of steps : 1603
# ====================
# Episode n°398
# reward : -17.0
# Number of steps : 1991
# ====================
# Episode n°399
# reward : -18.0
# Number of steps : 1744
# ====================
# Episode n°400
# reward : -18.0
# Number of steps : 1844
# ====================
# Episode n°401
# reward : -16.0
# Number of steps : 1759
# ====================
# Episode n°402
# reward : -17.0
# Number of steps : 1680
# ====================
# Episode n°403
# reward : -15.0
# Number of steps : 1849
# ====================
# Episode n°404
# reward : -16.0
# Number of steps : 1574
# ====================
# Episode n°405
# reward : -18.0
# Number of steps : 1496
# ====================
# Episode n°406
# reward : -14.0
# Number of steps : 1858
# ====================
# Episode n°407
# reward : -15.0
# Number of steps : 2037
# ====================
# Episode n°408
# reward : -15.0
# Number of steps : 1798
# ====================
# Episode n°409
# reward : -17.0
# Number of steps : 1724
# ====================
# Episode n°410
# reward : -18.0
# Number of steps : 1583
# ====================
# Episode n°411
# reward : -16.0
# Number of steps : 1762
# ====================
# Episode n°412
# reward : -13.0
# Number of steps : 2078
# ====================
# Episode n°413
# reward : -18.0
# Number of steps : 1469
# ====================
# Episode n°414
# reward : -19.0
# Number of steps : 1654
# ====================
# Episode n°415
# reward : -14.0
# Number of steps : 1906
# ====================
# Episode n°416
# reward : -17.0
# Number of steps : 1730
# ====================
# Episode n°417
# reward : -15.0
# Number of steps : 1892
# ====================
# Episode n°418
# reward : -15.0
# Number of steps : 1764
# ====================
# Episode n°419
# reward : -18.0
# Number of steps : 1588
# ====================
# Episode n°420
# reward : -17.0
# Number of steps : 1688
# ====================
# Episode n°421
# reward : -16.0
# Number of steps : 1941
# ====================
# Episode n°422
# reward : -13.0
# Number of steps : 2057
# ====================
# Episode n°423
# reward : -17.0
# Number of steps : 1798
# ====================
# Episode n°424
# reward : -14.0
# Number of steps : 1899
# ====================
# Episode n°425
# reward : -18.0
# Number of steps : 1598
# ====================
# Episode n°426
# reward : -17.0
# Number of steps : 1756
# ====================
# Episode n°427
# reward : -15.0
# Number of steps : 1765
# ====================
# Episode n°428
# reward : -17.0
# Number of steps : 1893
# ====================
# Episode n°429
# reward : -19.0
# Number of steps : 1507
# ====================
# Episode n°430
# reward : -17.0
# Number of steps : 1740
# ====================
# Episode n°431
# reward : -14.0
# Number of steps : 2086
# ====================
# Episode n°432
# reward : -16.0
# Number of steps : 2017
# ====================
# Episode n°433
# reward : -12.0
# Number of steps : 2315
# ====================
# Episode n°434
# reward : -14.0
# Number of steps : 1939
# ====================
# Episode n°435
# reward : -11.0
# Number of steps : 2403
# ====================
# Episode n°436
# reward : -17.0
# Number of steps : 1764
# ====================
# Episode n°437
# reward : -16.0
# Number of steps : 1946
# ====================
# Episode n°438
# reward : -14.0
# Number of steps : 1984
# ====================
# Episode n°439
# reward : -16.0
# Number of steps : 1829
# ====================
# Episode n°440
# reward : -15.0
# Number of steps : 1946
# ====================
# Episode n°441
# reward : -11.0
# Number of steps : 2228
# ====================
# Episode n°442
# reward : -15.0
# Number of steps : 1827
# ====================
# Episode n°443
# reward : -16.0
# Number of steps : 1792
# ====================
# Episode n°444
# reward : -10.0
# Number of steps : 2479
# ====================
# Episode n°445
# reward : -16.0
# Number of steps : 1763
# ====================
# Episode n°446
# reward : -16.0
# Number of steps : 2137
# ====================
# Episode n°447
# reward : -15.0
# Number of steps : 2322
# ====================
# Episode n°448
# reward : -9.0
# Number of steps : 2539
# ====================
# Episode n°449
# reward : -16.0
# Number of steps : 1937
# ====================
# Episode n°450
# reward : -15.0
# Number of steps : 1826
# ====================
# Episode n°451
# reward : -14.0
# Number of steps : 1876
# ====================
# Episode n°452
# reward : -15.0
# Number of steps : 1956
# ====================
# Episode n°453
# reward : -17.0
# Number of steps : 2056
# ====================
# Episode n°454
# reward : -17.0
# Number of steps : 1654
# ====================
# Episode n°455
# reward : -13.0
# Number of steps : 2116
# ====================
# Episode n°456
# reward : -15.0
# Number of steps : 1878
# ====================
# Episode n°457
# reward : -11.0
# Number of steps : 2316
# ====================
# Episode n°458
# reward : -15.0
# Number of steps : 1573
# ====================
# Episode n°459
# reward : -16.0
# Number of steps : 1676
# ====================
# Episode n°460
# reward : -16.0
# Number of steps : 2042
# ====================
# Episode n°461
# reward : -11.0
# Number of steps : 2383
# ====================
# Episode n°462
# reward : -19.0
# Number of steps : 1685
# ====================
# Episode n°463
# reward : -17.0
# Number of steps : 1749
# ====================
# Episode n°464
# reward : -19.0
# Number of steps : 1558
# ====================
# Episode n°465
# reward : -17.0
# Number of steps : 1812
# ====================
# Episode n°466
# reward : -16.0
# Number of steps : 1899
# ====================
# Episode n°467
# reward : -17.0
# Number of steps : 1740
# ====================
# Episode n°468
# reward : -12.0
# Number of steps : 2244
# ====================
# Episode n°469
# reward : -16.0
# Number of steps : 1994
# ====================
# Episode n°470
# reward : -9.0
# Number of steps : 2587
# ====================
# Episode n°471
# reward : -14.0
# Number of steps : 1874
# ====================
# Episode n°472
# reward : -11.0
# Number of steps : 2730
# ====================
# Episode n°473
# reward : -4.0
# Number of steps : 3137
# ====================
# Episode n°474
# reward : -9.0
# Number of steps : 2693
# ====================
# Episode n°475
# reward : -13.0
# Number of steps : 2183
# ====================
# Episode n°476
# reward : -16.0
# Number of steps : 1946
# ====================
# Episode n°477
# reward : -10.0
# Number of steps : 2454
# ====================
# Episode n°478
# reward : -15.0
# Number of steps : 1764
# ====================
# Episode n°479
# reward : -14.0
# Number of steps : 1948
# ====================
# Episode n°480
# reward : -14.0
# Number of steps : 2046
# ====================
# Episode n°481
# reward : -16.0
# Number of steps : 1890
# ====================
# Episode n°482
# reward : -13.0
# Number of steps : 1925
# ====================
# Episode n°483
# reward : -7.0
# Number of steps : 2679
# ====================
# Episode n°484
# reward : -11.0
# Number of steps : 2132
# ====================
# Episode n°485
# reward : -16.0
# Number of steps : 1850
# ====================
# Episode n°486
# reward : -16.0
# Number of steps : 1827
# ====================
# Episode n°487
# reward : -13.0
# Number of steps : 2067
# ====================
# Episode n°488
# reward : -11.0
# Number of steps : 2222
# ====================
# Episode n°489
# reward : -16.0
# Number of steps : 1907
# ====================
# Episode n°490
# reward : -15.0
# Number of steps : 2154
# ====================
# Episode n°491
# reward : -16.0
# Number of steps : 1782
# ====================
# Episode n°492
# reward : -11.0
# Number of steps : 2366
# ====================
# Episode n°493
# reward : -14.0
# Number of steps : 1942
# ====================
# Episode n°494
# reward : -7.0
# Number of steps : 2810
# ====================
# Episode n°495
# reward : -13.0
# Number of steps : 2267
# ====================
# Episode n°496
# reward : -15.0
# Number of steps : 2355
# ====================
# Episode n°497
# reward : -12.0
# Number of steps : 2031
# ====================
# Episode n°498
# reward : -11.0
# Number of steps : 2371
# ====================
# Episode n°499
# reward : -13.0
# Number of steps : 1983
# ====================
# Episode n°500
# reward : -14.0
# Number of steps : 2149
# ====================
# Episode n°501
# reward : -15.0
# Number of steps : 2086
# ====================
# Episode n°502
# reward : -14.0
# Number of steps : 1976
# ====================
# Episode n°503
# reward : -13.0
# Number of steps : 2027
# ====================
# Episode n°504
# reward : -13.0
# Number of steps : 2057
# ====================
# Episode n°505
# reward : -13.0
# Number of steps : 2141
# ====================
# Episode n°506
# reward : -14.0
# Number of steps : 2255
# ====================
# Episode n°507
# reward : -16.0
# Number of steps : 1888
# ====================
# Episode n°508
# reward : -18.0
# Number of steps : 1769
# ====================
# Episode n°509
# reward : -13.0
# Number of steps : 2380
# ====================
# Episode n°510
# reward : -8.0
# Number of steps : 3066
# ====================
# Episode n°511
# reward : -13.0
# Number of steps : 2419
# ====================
# Episode n°512
# reward : -9.0
# Number of steps : 2724
# ====================
# Episode n°513
# reward : -13.0
# Number of steps : 2332
# ====================
# Episode n°514
# reward : -11.0
# Number of steps : 2563
# ====================
# Episode n°515
# reward : -18.0
# Number of steps : 1793
# ====================
# Episode n°516
# reward : -12.0
# Number of steps : 2284
# ====================
# Episode n°517
# reward : -13.0
# Number of steps : 1978
# ====================
# Episode n°518
# reward : -16.0
# Number of steps : 1940
# ====================
# Episode n°519
# reward : -13.0
# Number of steps : 2101
# ====================
# Episode n°520
# reward : -19.0
# Number of steps : 1637
# ====================
# Episode n°521
# reward : -9.0
# Number of steps : 2706
# ====================
# Episode n°522
# reward : -11.0
# Number of steps : 2385
# ====================
# Episode n°523
# reward : -15.0
# Number of steps : 1872
# ====================
# Episode n°524
# reward : -14.0
# Number of steps : 1975
# ====================
# Episode n°525
# reward : -13.0
# Number of steps : 1972
# ====================
# Episode n°526
# reward : -14.0
# Number of steps : 2021
# ====================
# Episode n°527
# reward : -16.0
# Number of steps : 1936
# ====================
# Episode n°528
# reward : -14.0
# Number of steps : 2029
# ====================
# Episode n°529
# reward : -12.0
# Number of steps : 2395
# ====================
# Episode n°530
# reward : -14.0
# Number of steps : 2448
# ====================
# Episode n°531
# reward : -16.0
# Number of steps : 2133
# ====================
# Episode n°532
# reward : -16.0
# Number of steps : 1784
# ====================
# Episode n°533
# reward : -11.0
# Number of steps : 2632
# ====================
# Episode n°534
# reward : -18.0
# Number of steps : 2078
# ====================
# Episode n°535
# reward : -17.0
# Number of steps : 2179
# ====================
# Episode n°536
# reward : -19.0
# Number of steps : 1971
# ====================
# Episode n°537
# reward : -15.0
# Number of steps : 2105
# ====================
# Episode n°538
# reward : -14.0
# Number of steps : 2452
# ====================
# Episode n°539
# reward : -14.0
# Number of steps : 2505
# ====================
# Episode n°540
# reward : -15.0
# Number of steps : 2235
# ====================
# Episode n°541
# reward : -17.0
# Number of steps : 1961
# ====================
# Episode n°542
# reward : -13.0
# Number of steps : 2599
# ====================
# Episode n°543
# reward : -13.0
# Number of steps : 2432
# ====================
# Episode n°544
# reward : -10.0
# Number of steps : 2761
# ====================
# Episode n°545
# reward : -12.0
# Number of steps : 2327
# ====================
# Episode n°546
# reward : -12.0
# Number of steps : 2863
# ====================
# Episode n°547
# reward : -13.0
# Number of steps : 2431
# ====================
# Episode n°548
# reward : -14.0
# Number of steps : 2641
# ====================
# Episode n°549
# reward : -14.0
# Number of steps : 2645
# ====================
# Episode n°550
# reward : -12.0
# Number of steps : 2870
# ====================
# Episode n°551
# reward : -15.0
# Number of steps : 2740
# ====================
# Episode n°552
# reward : -14.0
# Number of steps : 2672
# ====================
# Episode n°553
# reward : -16.0
# Number of steps : 2107
# ====================
# Episode n°554
# reward : -14.0
# Number of steps : 2386
# ====================
# Episode n°555
# reward : -11.0
# Number of steps : 2363
# ====================
# Episode n°556
# reward : -14.0
# Number of steps : 2420
# ====================
# Episode n°557
# reward : -7.0
# Number of steps : 3364
# ====================
# Episode n°558
# reward : -10.0
# Number of steps : 2514
# ====================
# Episode n°559
# reward : -15.0
# Number of steps : 2263
# ====================
# Episode n°560
# reward : -14.0
# Number of steps : 2665
# ====================
# Episode n°561
# reward : -15.0
# Number of steps : 2406
# ====================
# Episode n°562
# reward : -10.0
# Number of steps : 2601
# ====================
# Episode n°563
# reward : -13.0
# Number of steps : 2459
# ====================
# Episode n°564
# reward : -11.0
# Number of steps : 2901
# ====================
# Episode n°565
# reward : -11.0
# Number of steps : 2661
# ====================
# Episode n°566
# reward : -10.0
# Number of steps : 2562
# ====================
# Episode n°567
# reward : -10.0
# Number of steps : 3013
# ====================
# Episode n°568
# reward : -17.0
# Number of steps : 2283
# ====================
# Episode n°569
# reward : -16.0
# Number of steps : 2456
# ====================
# Episode n°570
# reward : -9.0
# Number of steps : 3048
# ====================
# Episode n°571
# reward : -9.0
# Number of steps : 3155
# ====================
# Episode n°572
# reward : -18.0
# Number of steps : 1854
# ====================
# Episode n°573
# reward : -10.0
# Number of steps : 2750
# ====================
# Episode n°574
# reward : -8.0
# Number of steps : 2977
# ====================
# Episode n°575
# reward : -9.0
# Number of steps : 2700
# ====================
# Episode n°576
# reward : -7.0
# Number of steps : 3080
# ====================
# Episode n°577
# reward : -12.0
# Number of steps : 2938
# ====================
# Episode n°578
# reward : -15.0
# Number of steps : 2173
# ====================
# Episode n°579
# reward : -12.0
# Number of steps : 2701
# ====================
# Episode n°580
# reward : -11.0
# Number of steps : 2765
# ====================
# Episode n°581
# reward : -8.0
# Number of steps : 2908
# ====================
# Episode n°582
# reward : -10.0
# Number of steps : 2587
# ====================
# Episode n°583
# reward : -12.0
# Number of steps : 2410
# ====================
# Episode n°584
# reward : -11.0
# Number of steps : 2827
# ====================
# Episode n°585
# reward : -5.0
# Number of steps : 3014
# ====================
# Episode n°586
# reward : -12.0
# Number of steps : 2756
# ====================
# Episode n°587
# reward : -12.0
# Number of steps : 2754
# ====================
# Episode n°588
# reward : -12.0
# Number of steps : 2966
# ====================
# Episode n°589
# reward : -9.0
# Number of steps : 2707
# ====================
# Episode n°590
# reward : -7.0
# Number of steps : 2688
# ====================
# Episode n°591
# reward : -3.0
# Number of steps : 3256
# ====================
# Episode n°592
# reward : -15.0
# Number of steps : 2425
# ====================
# Episode n°593
# reward : -6.0
# Number of steps : 2872
# ====================
# Episode n°594
# reward : -3.0
# Number of steps : 3744
# ====================
# Episode n°595
# reward : -4.0
# Number of steps : 3160
# ====================
# Episode n°596
# reward : -8.0
# Number of steps : 2813
# ====================
# Episode n°597
# reward : -1.0
# Number of steps : 3683
# ====================
# Episode n°598
# reward : -11.0
# Number of steps : 2510
# ====================
# Episode n°599
# reward : -3.0
# Number of steps : 3227
# ====================
# Episode n°600
# reward : -8.0
# Number of steps : 2442
# ====================
# Episode n°601
# reward : -6.0
# Number of steps : 2640
# ====================
# Episode n°602
# reward : -9.0
# Number of steps : 2449
# ====================
# Episode n°603
# reward : -5.0
# Number of steps : 2785
# ====================
# Episode n°604
# reward : -10.0
# Number of steps : 2303
# ====================
# Episode n°605
# reward : 6.0
# Number of steps : 2924
# ====================
# Episode n°606
# reward : -1.0
# Number of steps : 3833
# ====================
# Episode n°607
# reward : -8.0
# Number of steps : 3038
# ====================
# Episode n°608
# reward : -9.0
# Number of steps : 2861
# ====================
# Episode n°609
# reward : -15.0
# Number of steps : 2073
# ====================
# Episode n°610
# reward : -10.0
# Number of steps : 2543
# ====================
# Episode n°611
# reward : -13.0
# Number of steps : 2341
# ====================
# Episode n°612
# reward : -13.0
# Number of steps : 2499
# ====================
# Episode n°613
# reward : -8.0
# Number of steps : 2885
# ====================
# Episode n°614
# reward : -9.0
# Number of steps : 2779
# ====================
# Episode n°615
# reward : -13.0
# Number of steps : 2363
# ====================
# Episode n°616
# reward : -3.0
# Number of steps : 3232
# ====================
# Episode n°617
# reward : -12.0
# Number of steps : 2117
# ====================
# Episode n°618
# reward : -5.0
# Number of steps : 3024
# ====================
# Episode n°619
# reward : -3.0
# Number of steps : 3247
# ====================
# Episode n°620
# reward : -4.0
# Number of steps : 3293
# ====================
# Episode n°621
# reward : -15.0
# Number of steps : 2103
# ====================
# Episode n°622
# reward : -12.0
# Number of steps : 2191
# ====================
# Episode n°623
# reward : -9.0
# Number of steps : 2608
# ====================
# Episode n°624
# reward : -6.0
# Number of steps : 2956
# ====================
# Episode n°625
# reward : -9.0
# Number of steps : 2796
# ====================
# Episode n°626
# reward : -4.0
# Number of steps : 3294
# ====================
# Episode n°627
# reward : -2.0
# Number of steps : 3489
# ====================
# Episode n°628
# reward : -2.0
# Number of steps : 3580
# ====================
# Episode n°629
# reward : -9.0
# Number of steps : 3139
# ====================
# Episode n°630
# reward : -4.0
# Number of steps : 3243
# ====================
# Episode n°631
# reward : -6.0
# Number of steps : 3212
# ====================
# Episode n°632
# reward : -3.0
# Number of steps : 3099
# ====================
# Episode n°633
# reward : -3.0
# Number of steps : 3132
# ====================
# Episode n°634
# reward : -10.0
# Number of steps : 2493
# ====================
# Episode n°635
# reward : -9.0
# Number of steps : 2857
# ====================
# Episode n°636
# reward : -11.0
# Number of steps : 2998
# ====================
# Episode n°637
# reward : -11.0
# Number of steps : 2674
# ====================
# Episode n°638
# reward : 7.0
# Number of steps : 2975
# ====================
# Episode n°639
# reward : -7.0
# Number of steps : 2823
# ====================
# Episode n°640
# reward : -10.0
# Number of steps : 2546
# ====================
# Episode n°641
# reward : -5.0
# Number of steps : 3331
# ====================
# Episode n°642
# reward : -4.0
# Number of steps : 3247
# ====================
# Episode n°643
# reward : -11.0
# Number of steps : 2393
# ====================
# Episode n°644
# reward : -8.0
# Number of steps : 2719
# ====================
# Episode n°645
# reward : -9.0
# Number of steps : 2891
# ====================
# Episode n°646
# reward : -2.0
# Number of steps : 3167
# ====================
# Episode n°647
# reward : -8.0
# Number of steps : 2994
# ====================
# Episode n°648
# reward : -1.0
# Number of steps : 3838
# ====================
# Episode n°649
# reward : -7.0
# Number of steps : 3086
# ====================
# Episode n°650
# reward : -4.0
# Number of steps : 2973
# ====================
# Episode n°651
# reward : -5.0
# Number of steps : 2957
# ====================
# Episode n°652
# reward : -7.0
# Number of steps : 3060
# ====================
# Episode n°653
# reward : -2.0
# Number of steps : 3176
# ====================
# Episode n°654
# reward : -3.0
# Number of steps : 3233
# ====================
# Episode n°655
# reward : -2.0
# Number of steps : 3268
# ====================
# Episode n°656
# reward : -1.0
# Number of steps : 3317
# ====================
# Episode n°657
# reward : -9.0
# Number of steps : 2867
# ====================
# Episode n°658
# reward : 10.0
# Number of steps : 2552
# ====================
# Episode n°659
# reward : -11.0
# Number of steps : 2462
# ====================
# Episode n°660
# reward : -5.0
# Number of steps : 2749
# ====================
# Episode n°661
# reward : 2.0
# Number of steps : 3260
# ====================
# Episode n°662
# reward : -6.0
# Number of steps : 3118
# ====================
# ...
# Number of steps : 2750
# ====================
# Episode n°777
# reward : 5.0
# Number of steps : 3282
# ====================
# Episode n°778
# reward : 2.0
# Number of steps : 3826
# ====================
# Episode n°779
# reward : 14.0
# Number of steps : 2482
# ====================
# Episode n°780
# reward : 3.0
# Number of steps : 3568
# ====================
# Episode n°781
# reward : 6.0
# Number of steps : 3276
# ====================
# Episode n°782
# reward : 8.0
# Number of steps : 2877
# ====================
# Episode n°783
# reward : 12.0
# Number of steps : 2536
# ====================
# Episode n°784
# reward : 5.0
# Number of steps : 3263
# ====================
# Episode n°785
# reward : 16.0
# Number of steps : 2419
# ====================
# Episode n°786
# reward : 7.0
# Number of steps : 2816
# ====================
# Episode n°787
# reward : 2.0
# Number of steps : 3234
# ====================
# Episode n°788
# reward : 6.0
# Number of steps : 3118
# ====================
# Episode n°789
# reward : 11.0
# Number of steps : 2506
# ====================
# Episode n°790
# reward : 4.0
# Number of steps : 3216
# ====================
# Episode n°791
# reward : 15.0
# Number of steps : 2357
# ====================
# Episode n°792
# reward : 13.0
# Number of steps : 2493
# ====================
# Episode n°793
# reward : 17.0
# Number of steps : 2231
# ====================
# Episode n°794
# reward : 11.0
# Number of steps : 2916
# ====================
# Episode n°795
# reward : 7.0
# Number of steps : 2941
# ====================
# Episode n°796
# reward : 3.0
# Number of steps : 3294
# ====================
# Episode n°797
# reward : 11.0
# Number of steps : 3101
# ====================
# Episode n°798
# reward : 14.0
# Number of steps : 2358
# ====================
# Episode n°799
# reward : 12.0
# Number of steps : 3266
# ====================
# Episode n°800
# reward : 14.0
# Number of steps : 2472
# ====================
# Episode n°801
# reward : 10.0
# Number of steps : 2884
# ====================
# Episode n°802
# reward : 8.0
# Number of steps : 3012
# ====================
# Episode n°803
# reward : 6.0
# Number of steps : 3280
# ====================
# Episode n°804
# reward : 11.0
# Number of steps : 3126
# ====================
# Episode n°805
# reward : 7.0
# Number of steps : 3112
# ====================
# Episode n°806
# reward : 13.0
# Number of steps : 2637
# ====================
# Episode n°807
# reward : 10.0
# Number of steps : 2827
# ====================
# Episode n°808
# reward : 14.0
# Number of steps : 2692
# ====================
# Episode n°809
# reward : 13.0
# Number of steps : 2890
# ====================
# Episode n°810
# reward : 9.0
# Number of steps : 3527
# ====================
# Episode n°811
# reward : 9.0
# Number of steps : 3019
# ====================
# Episode n°812
# reward : 10.0
# Number of steps : 3085
# ====================
# Episode n°813
# reward : 14.0
# Number of steps : 2769
# ====================
# Episode n°814
# reward : 7.0
# Number of steps : 3158
# ====================
# Episode n°815
# reward : 8.0
# Number of steps : 3582
# ====================
# Episode n°816
# reward : 11.0
# Number of steps : 2891
# ====================
# Episode n°817
# reward : 9.0
# Number of steps : 2975
# ====================
# Episode n°818
# reward : 11.0
# Number of steps : 2554
# ====================
# Episode n°819
# reward : 12.0
# Number of steps : 2510
# ====================
# Episode n°820
# reward : 10.0
# Number of steps : 2680
# ====================
# Episode n°821
# reward : 2.0
# Number of steps : 3606
# ====================
# Episode n°822
# reward : 8.0
# Number of steps : 2801
# ====================
# Episode n°823
# reward : -2.0
# Number of steps : 3662
# ====================
# Episode n°824
# reward : 5.0
# Number of steps : 3248
# ====================
# Episode n°825
# reward : 8.0
# Number of steps : 3396
# ====================
# Episode n°826
# reward : 15.0
# Number of steps : 2255
# ====================
# Episode n°827
# reward : 10.0
# Number of steps : 2886
# ====================
# Episode n°828
# reward : 10.0
# Number of steps : 2799
# ====================
# Episode n°829
# reward : 14.0
# Number of steps : 2392
# ====================
# Episode n°830
# reward : 11.0
# Number of steps : 2870
# ====================
# Episode n°831
# reward : 6.0
# Number of steps : 3317
# ====================
# Episode n°832
# reward : 3.0
# Number of steps : 3636
# ====================
# Episode n°833
# reward : 9.0
# Number of steps : 3000
# ====================
# Episode n°834
# reward : 10.0
# Number of steps : 3170
# ====================
# Episode n°835
# reward : 15.0
# Number of steps : 2197
# ====================
# Episode n°836
# reward : 8.0
# Number of steps : 3212
# ====================
# Episode n°837
# reward : 15.0
# Number of steps : 2425
# ====================
# Episode n°838
# reward : 8.0
# Number of steps : 3303
# ====================
# Episode n°839
# reward : 8.0
# Number of steps : 3230
# ====================
# Episode n°840
# reward : 7.0
# Number of steps : 2916
# ====================
# Episode n°841
# reward : 7.0
# Number of steps : 2830
# ====================
# Episode n°842
# reward : 11.0
# Number of steps : 2755
# ====================
# Episode n°843
# reward : 5.0
# Number of steps : 3469
# ====================
# Episode n°844
# reward : 13.0
# Number of steps : 2831
# ====================
# Episode n°845
# reward : 6.0
# Number of steps : 3672
# ====================
# Episode n°846
# reward : 14.0
# Number of steps : 2187
# ====================
# Episode n°847
# reward : 7.0
# Number of steps : 3349
# ====================
# Episode n°848
# reward : 5.0
# Number of steps : 3692
# ====================
# Episode n°849
# reward : 14.0
# Number of steps : 2431
# ====================
# Episode n°850
# reward : 6.0
# Number of steps : 3320
# ====================
# Episode n°851
# reward : 5.0
# Number of steps : 3642
# ====================
# Episode n°852
# reward : 6.0
# Number of steps : 3240
# ====================
# Episode n°853
# reward : 12.0
# Number of steps : 2629
# ====================
# Episode n°854
# reward : 4.0
# Number of steps : 3142
# ====================
# Episode n°855
# reward : 11.0
# Number of steps : 2595
# ====================
# Episode n°856
# reward : 10.0
# Number of steps : 2634
# ====================
# Episode n°857
# reward : 10.0
# Number of steps : 2917
# ====================
# Episode n°858
# reward : 2.0
# Number of steps : 3558
# ====================
# Episode n°859
# reward : 4.0
# Number of steps : 3578
# ====================
# Episode n°860
# reward : 8.0
# Number of steps : 3027
# ====================
# Episode n°861
# reward : 6.0
# Number of steps : 3350
# ====================
# Episode n°862
# reward : 8.0
# Number of steps : 3242
# ====================
# Episode n°863
# reward : 6.0
# Number of steps : 3130
# ====================
# Episode n°864
# reward : 10.0
# Number of steps : 3269
# ====================
# Episode n°865
# reward : 10.0
# Number of steps : 2676
# ====================
# Episode n°866
# reward : 5.0
# Number of steps : 4002
# ====================
# Episode n°867
# reward : 11.0
# Number of steps : 2546
# ====================
# Episode n°868
# reward : 13.0
# Number of steps : 2779
# ====================
# Episode n°869
# reward : 5.0
# Number of steps : 3496
# ====================
# Episode n°870
# reward : 12.0
# Number of steps : 3087
# ====================
# Episode n°871
# reward : 3.0
# Number of steps : 3540
# ====================
# Episode n°872
# reward : 13.0
# Number of steps : 2413
# ====================
# Episode n°873
# reward : 8.0
# Number of steps : 3588
# ====================
# Episode n°874
# reward : 11.0
# Number of steps : 2876
# ====================
# Episode n°875
# reward : 1.0
# Number of steps : 3861
# ====================
# Episode n°876
# reward : 1.0
# Number of steps : 3110
# ====================
# Episode n°877
# reward : 11.0
# Number of steps : 2549
# ====================
# Episode n°878
# reward : 15.0
# Number of steps : 2181
# ====================
# Episode n°879
# reward : 9.0
# Number of steps : 2620
# ====================
# Episode n°880
# reward : 5.0
# Number of steps : 3589
# ====================
# Episode n°881
# reward : 3.0
# Number of steps : 3474
# ====================
# Episode n°882
# reward : 4.0
# Number of steps : 3439
# ====================
# Episode n°883
# reward : 7.0
# Number of steps : 2953
# ====================
# Episode n°884
# reward : 12.0
# Number of steps : 2674
# ====================
# Episode n°885
# reward : 9.0
# Number of steps : 2703
# ====================
# Episode n°886
# reward : 12.0
# Number of steps : 2705
# ====================
# Episode n°887
# reward : 14.0
# Number of steps : 2712
# ====================
# Episode n°888
# reward : 13.0
# Number of steps : 2604
# ====================
# Episode n°889
# reward : 3.0
# Number of steps : 3498
# ====================
# Episode n°890
# reward : 5.0
# Number of steps : 3099
# ====================
# Episode n°891
# reward : 9.0
# Number of steps : 3041
# ====================
# Episode n°892
# reward : 17.0
# Number of steps : 2363
# ====================
# Episode n°893
# reward : 11.0
# Number of steps : 2735
# ====================
# Episode n°894
# reward : 14.0
# Number of steps : 2705
# ====================
# Episode n°895
# reward : 11.0
# Number of steps : 2878
# ====================
# Episode n°896
# reward : 8.0
# Number of steps : 2833
# ====================
# Episode n°897
# reward : 8.0
# Number of steps : 3164
# ====================
# Episode n°898
# reward : 15.0
# Number of steps : 2314
# ====================
# Episode n°899
# reward : 10.0
# Number of steps : 2915
# ====================
# Episode n°900
# reward : 5.0
# Number of steps : 3481
# ====================
# Episode n°901
# reward : 9.0
# Number of steps : 2633
# ====================
# Episode n°902
# reward : -2.0
# Number of steps : 3662
# ====================
# Episode n°903
# reward : 11.0
# Number of steps : 3527
# ====================
# Episode n°904
# reward : 11.0
# Number of steps : 2548
# ====================
# Episode n°905
# reward : 9.0
# Number of steps : 2652
# ====================
# Episode n°906
# reward : 14.0
# Number of steps : 2545
# ====================
# Episode n°907
# reward : 2.0
# Number of steps : 2752
# ====================
# Episode n°908
# reward : 9.0
# Number of steps : 2699
# ====================
# Episode n°909
# reward : 13.0
# Number of steps : 2473
# ====================
# Episode n°910
# reward : 7.0
# Number of steps : 3068
# ====================
# Episode n°911
# reward : 2.0
# Number of steps : 3040
# ====================
# Episode n°912
# reward : 7.0
# Number of steps : 4221
# ====================
# Episode n°913
# reward : 14.0
# Number of steps : 2322
# ====================
# Episode n°914
# reward : 12.0
# Number of steps : 3034
# ====================
# Episode n°915
# reward : 4.0
# Number of steps : 3505
# ====================
# Episode n°916
# reward : 9.0
# Number of steps : 2705
# ====================
# Episode n°917
# reward : 8.0
# Number of steps : 3137
# ====================
# Episode n°918
# reward : 15.0
# Number of steps : 2163
# ====================
# Episode n°919
# reward : 7.0
# Number of steps : 3101
# ====================
# Episode n°920
# reward : 13.0
# Number of steps : 2642
# ====================
# Episode n°921
# reward : 13.0
# Number of steps : 2662
# ====================
# Episode n°922
# reward : 8.0
# Number of steps : 2943
# ====================
# Episode n°923
# reward : 13.0
# Number of steps : 2737
# ====================
# Episode n°924
# reward : 13.0
# Number of steps : 2458
# ====================
# Episode n°925
# reward : 1.0
# Number of steps : 3586
# ====================
# Episode n°926
# reward : 1.0
# Number of steps : 4158
# ====================
# Episode n°927
# reward : 11.0
# Number of steps : 2667
# ====================
# Episode n°928
# reward : 8.0
# Number of steps : 2800
# ====================
# Episode n°929
# reward : 6.0
# Number of steps : 3111
# ====================
# Episode n°930
# reward : 13.0
# Number of steps : 2429
# ====================
# Episode n°931
# reward : 13.0
# Number of steps : 2671
# ====================
# Episode n°932
# reward : -2.0
# Number of steps : 3446
# ====================
# Episode n°933
# reward : 9.0
# Number of steps : 2906
# ====================
# Episode n°934
# reward : 5.0
# Number of steps : 3090
# ====================
# Episode n°935
# reward : 4.0
# Number of steps : 3362
# ====================
# Episode n°936
# reward : 3.0
# Number of steps : 4207
# ====================
# Episode n°937
# reward : 12.0
# Number of steps : 2742
# ====================
# Episode n°938
# reward : 4.0
# Number of steps : 3989
# ====================
# Episode n°939
# reward : 14.0
# Number of steps : 2284
# ====================
# Episode n°940
# reward : 6.0
# Number of steps : 2861
# ====================
# Episode n°941
# reward : 11.0
# Number of steps : 3570
# ====================
# Episode n°942
# reward : -4.0
# Number of steps : 3088
# ====================
# Episode n°943
# reward : 14.0
# Number of steps : 2486
# ====================
# Episode n°944
# reward : 13.0
# Number of steps : 2658
# ====================
# Episode n°945
# reward : 8.0
# Number of steps : 3140
# ====================
# Episode n°946
# reward : 2.0
# Number of steps : 3227
# ====================
# Episode n°947
# reward : 12.0
# Number of steps : 2359
# ====================
# Episode n°948
# reward : 10.0
# Number of steps : 3369
# ====================
# Episode n°949
# reward : 16.0
# Number of steps : 2354
# ====================
# Episode n°950
# reward : 8.0
# Number of steps : 3274
# ====================
# Episode n°951
# reward : 9.0
# Number of steps : 2914
# ====================
# Episode n°952
# reward : 12.0
# Number of steps : 2951
# ====================
# Episode n°953
# reward : 11.0
# Number of steps : 2504
# ====================
# Episode n°954
# reward : 12.0
# Number of steps : 2823
# ====================
# Episode n°955
# reward : 15.0
# Number of steps : 2660
# ====================
# Episode n°956
# reward : -1.0
# Number of steps : 4435
# ====================
# Episode n°957
# reward : 13.0
# Number of steps : 3136
# ====================
# Episode n°958
# reward : 12.0
# Number of steps : 2786
# ====================
# Episode n°959
# reward : 11.0
# Number of steps : 2844
# ====================
# Episode n°960
# reward : 4.0
# Number of steps : 3285
# ====================
# Episode n°961
# reward : 13.0
# Number of steps : 2819
# ====================
# Episode n°962
# reward : 11.0
# Number of steps : 2900
# ====================
# Episode n°963
# reward : 9.0
# Number of steps : 2735
# ====================
# Episode n°964
# reward : 13.0
# Number of steps : 2427
# ====================
# Episode n°965
# reward : 2.0
# Number of steps : 3776
# ====================
# Episode n°966
# reward : 8.0
# Number of steps : 2932
# ====================
# Episode n°967
# reward : -2.0
# Number of steps : 3736
# ====================
# Episode n°968
# reward : 4.0
# Number of steps : 3340
# ====================
# Episode n°969
# reward : 11.0
# Number of steps : 2927
# ====================
# Episode n°970
# reward : 14.0
# Number of steps : 2117
# ====================
# Episode n°971
# reward : 3.0
# Number of steps : 3839
# ====================
# Episode n°972
# reward : 2.0
# Number of steps : 3411
# ====================
# Episode n°973
# reward : 11.0
# Number of steps : 2875
# ====================
# Episode n°974
# reward : -4.0
# Number of steps : 3419
# ====================
# Episode n°975
# reward : 7.0
# Number of steps : 3010
# ====================
# Episode n°976
# reward : 11.0
# Number of steps : 2728
# ====================
# Episode n°977
# reward : 10.0
# Number of steps : 3106
# ====================
# Episode n°978
# reward : 3.0
# Number of steps : 3570
# ====================
# Episode n°979
# reward : 12.0
# Number of steps : 3001
# ====================
# Episode n°980
# reward : 11.0
# Number of steps : 2889
# ====================
# Episode n°981
# reward : 17.0
# Number of steps : 2542
# ====================
# Episode n°982
# reward : 13.0
# Number of steps : 2934
# ====================
# Episode n°983
# reward : 5.0
# Number of steps : 3241
# ====================
# Episode n°984
# reward : 9.0
# Number of steps : 3063
# ====================
# Episode n°985
# reward : 12.0
# Number of steps : 2659
# ====================
# Episode n°986
# reward : 5.0
# Number of steps : 3424
# ====================
# Episode n°987
# reward : 14.0
# Number of steps : 2708
# ====================
# Episode n°988
# reward : 3.0
# Number of steps : 3374
# ====================
# Episode n°989
# reward : 12.0
# Number of steps : 2589
# ====================
# Episode n°990
# reward : 13.0
# Number of steps : 2617
# ====================
# Episode n°991
# reward : 13.0
# Number of steps : 2397
# ====================
# Episode n°992
# reward : 15.0
# Number of steps : 2853
# ====================
# Episode n°993
# reward : 8.0
# Number of steps : 2844
# ====================
# Episode n°994
# reward : -4.0
# Number of steps : 3222
# ====================
# Episode n°995
# reward : 10.0
# Number of steps : 2964
# ====================
# Episode n°996
# reward : 5.0
# Number of steps : 3362
# ====================
# Episode n°997
# reward : 10.0
# Number of steps : 2928
# ====================
# Episode n°998
# reward : 12.0
# Number of steps : 2542
# ====================
# Episode n°999
# reward : 7.0
# Number of steps : 3034
# ====================

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
pong_files = [
    "scores_DoublePong3-Step.csv",
    "scores_DuelingPong1-Step.csv",
    "scores_DuelingPong3-Step.csv",
    "scores_PER_DuelingPong3-Step.csv"
]

qbert_files = [
    "scoreQbertN3DoubleNoPrio.csv",
    "scores_DoubleQbert1-Step.csv",
    "scores_DoubleQbert3-Step.csv",
    "scores_DuelingQbert3-Step.csv"
]


def plot_progression(file_list, game_name, window=20):
    plt.figure(figsize=(12, 6))
    
    for file in file_list:
        
        df = pd.read_csv(file)
        df.columns = [c.capitalize() for c in df.columns]

        df = df.sort_values('Episode')
        
        smoothed = df['Reward'].rolling(window=window, min_periods=1).mean()
        
        label = file.replace('scores_', '').replace('.csv', '')
        line, = plt.plot(df['Episode'], smoothed, label=label, linewidth=2)
        plt.plot(df['Episode'], df['Reward'], alpha=0.15, color=line.get_color())
        

    plt.title(f"Score's evolution by episode - {game_name} (moving average {window} episodes)")
    plt.xlabel("Episodes")
    plt.ylabel("Score (Reward)")
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()


plot_progression(pong_files, "Pong")
plot_progression(qbert_files, "Qbert")
